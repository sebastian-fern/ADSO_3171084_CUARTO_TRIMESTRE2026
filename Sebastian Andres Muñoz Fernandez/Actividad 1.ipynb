# %%
[10:32 AM, 2/11/2026] +57 304 3024355: class Libro:
    def _init_(self, titulo, precio):
        self._titulo = titulo
        self._precio = precio

    def get_precio(self):
        return self._precio

    def set_precio(self, nuevo_precio):
        if isinstance(nuevo_precio, (int, float)) and nuevo_precio > 0:
            self._precio = nuevo_precio
        else:
            print("El precio debe ser un número positivo.")

    def mostrar_info(self):
        print(f"\nTitulo: {self._titulo}")
        print(f"Precio: {self._precio}")
        print("----------------")


def main():
    libro1 = Libro("Python Profesional", 120000)  # crear objetos utilizando la plantilla
    libro2 = Libro("Java Profesional", 150000)

    # Mostrar informacion inicial
    print("Información inicial del libro:")
    libro1.mostrar_info()
    libro2.mostrar_info()

    # Mostrar precio actual
    print("Precio actual (Libro1):", libro1.get_precio())
    # intento de actualizacion no valida
    print("\nIntentando actualizar con un precio no válido...")
    libro1.set_precio(-10)
[10:40 AM, 2/11/2026] +57 304 3024355: # Actualizacion correcta
    print("\nActualizando precio correctamente...")
    libro1.set_precio(135000) # Corrected value for demonstration

    print("Nuevo precio (Libro1):", libro1.get_precio())

    print("\nPrograma finalizado.")

if _name_ == "_main_":
    main()
# Out:
#   File "/tmp/ipython-input-882677687.py", line 1
#     [10:32 AM, 2/11/2026] +57 304 3024355: class Libro:
#        ^
# SyntaxError: invalid syntax
