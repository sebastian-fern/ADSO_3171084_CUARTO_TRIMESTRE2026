# %%
class Vehiculo:
  def mover(seft):
    print(" El vehiculo se esta moviendo")


class Carro(Vehiculo):
  pass

def main():
  print("CLASE PADRE Y SU METODO\n")
  vehiculo1 = Vehiculo()
  vehiculo1.mover()

  print("ultirizaremos el metodo mover() de la clase padre em la clase HIJO\n")
  carro1 = Carro()
  carro1.mover()


if __name__ == "__main__":
  main()
# Out:
# CLASE PADRE Y SU METODO
#
#  El vehiculo se esta moviendo
# ultirizaremos el metodo mover() de la clase padre em la clase HIJO
#
#  El vehiculo se esta moviendo
